# %% [markdown]
# <a href="https://colab.research.google.com/github/Barsha-gc/Concept-and-technologies-of-AI/blob/main/Barshagc_workshop0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Given study time data (example)
time_data = [1, 4, 6, 2, 3.5, 5, 7, 2.5, 4.2]

# 1. Create empty lists
low = []
moderate = []
high = []

# 2. Iterate and classify
for t in time_data:
    if t < 3:
        low.append(t)
    elif 3 <= t <= 5:
        moderate.append(t)
    else:
        high.append(t)

# 3. Print results
print("Low Study Time (< 3 hrs):", low)
print("Moderate Study Time (3 - 5 hrs):", moderate)
print("High Study Time (> 5 hrs):", high)
# Out:
# Low Study Time (< 3 hrs): [1, 2, 2.5]
# Moderate Study Time (3 - 5 hrs): [4, 3.5, 5, 4.2]
# High Study Time (> 5 hrs): [6, 7]
